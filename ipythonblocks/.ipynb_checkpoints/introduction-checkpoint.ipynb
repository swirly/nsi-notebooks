# %% [markdown]
# # Introduction à ipythonblocks
#
# La bibliothèque ipythonblocks est une bibliothèque destinée à créer des grilles pour pouvoir apprendre la programmation. On peut avoir des cases de couleur, les modifier et faire des animations. Voici les principaux éléments à connaître sur cette bibliothèque
#
# ## BlockGrid
#
# Au cœur de cette bibliothèque se trouve le système de grille. La première chose à faire est d’importer l’objet grille de la bibliothèque et ensuite d’initialiser une grille et de l’afficher

# %%
from ipythonblocks import BlockGrid
grille = BlockGrid(20,10,fill=(0,0,0))
grille.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks0cf5b9ae-834c-4ef5-a5d6-d73ce8fe836c td {border: 1px solid white;}</style><table id="blocks0cf5b9ae-834c-4ef5-a5d6-d73ce8fe836c" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 11]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 12]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 13]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 14]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 15]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 16]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 17]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 18]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 19]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 1]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 2]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 3]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 5]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 6]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 7]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 8]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 9]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 10]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [1, 11]&#10;Color: (0, 0 ...

# %% [markdown]
# Sur la seconde ligne, le premier paramètre est la largeur de la grille (nombre de colonnes), le second est la hauteur de la grille (nombre de lignes) et le paramètre fill de la fonction correspond aux composantes rouges, vertes et bleues de la couleur de remplissage par défaut de la grille, dans le système RGB (dans cet exemple, c’est le noir).
#
# ## Accéder à un élément de la grille
#
# La grille est une liste double. On accède à un élément de la grille en donnant ses coordonnées entre crochets

# %%
bloc = grille[3,4]
bloc.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks6aefb317-1a1e-49de-8418-a54653991408 td {border: 0px solid white;}</style><table id="blocks6aefb317-1a1e-49de-8418-a54653991408" class="blockgrid"><tbody><tr><td title="Index: [3, 4]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td></tr></tbody></table>

# %% [markdown]
# **Attention !**
#
# **Les coordonnées d’un élément de la grille sont données dans l’ordre ligne, colonne,
# ce qui correspond à l’ordonnée en premier et l’abscisse en seconde.
# C’est contraire aux conventions habituelles, et c’est contraire à la définition de la grille
# ou le nombre de colonnes est donné en premier.**

# %% [markdown]
# ## Lire et modifier un élément de la grille
#
# On peut lire la couleur d’un élément de la grille soit en utilisant les propriétés de couleur individuelle, soit en utilisant la propriété rgb pour connaître la couleur
#
# On peut de la même façon fixer la couleur d’un élément de la grille.

# %%
print("rouge : "+str(bloc.red))
print("vert : "+str(bloc.green))
print("bleu : "+str(bloc.blue))
print(bloc.rgb)
# Out:
# rouge : 0
# vert : 0
# bleu : 0
# (0, 0, 0)

# %%
bloc.rgb=(100,210,200)
bloc.show()
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7eff8acd-ee88-4f46-9325-c772d09b75bc td {border: 0px solid white;}</style><table id="blocks7eff8acd-ee88-4f46-9325-c772d09b75bc" class="blockgrid"><tbody><tr><td title="Index: [3, 4]&#10;Color: (100, 210, 200)" style="width: 20px; height: 20px;background-color: rgb(100, 210, 200);"></td></tr></tbody></table>

# %% [markdown]
# ## Animations
#
# On peut utiliser sur la grille la méthode flash() qui permet
#
#  * d’effacer la sortie
#  * d’afficher la grille
#  * d’attendre un délai (qui peut être spécifié en paramètre et vaut 0.2s sinon)
#
# Voici un code exemple qui va créer une grille, puis réaliser une boucle 500 fois pour changer de façon aléatoire la couleur d’une case de la grille (on utilise la fonction randrange() )

# %%
from ipythonblocks import BlockGrid
import random

grille = BlockGrid(20,10,fill=(0,0,0))

for i in range(500):
    ligne = random.randrange(grille.height)
    colonne = random.randrange(grille.width)
    bloc=grille[ligne,colonne]
    bloc.red=random.randrange(256)
    bloc.green=random.randrange(256)
    bloc.blue=random.randrange(256)
    grille.flash(0.01)
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks7f20659e-90f5-4866-888b-94b2f1a8e30d td {border: 1px solid white;}</style><table id="blocks7f20659e-90f5-4866-888b-94b2f1a8e30d" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (0, 0, 0)" style="width: 20px; height: 20px;background-color: rgb(0, 0, 0);"></td><td title="Index: [0, 1]&#10;Color: (72, 240, 222)" style="width: 20px; height: 20px;background-color: rgb(72, 240, 222);"></td><td title="Index: [0, 2]&#10;Color: (182, 74, 90)" style="width: 20px; height: 20px;background-color: rgb(182, 74, 90);"></td><td title="Index: [0, 3]&#10;Color: (27, 124, 89)" style="width: 20px; height: 20px;background-color: rgb(27, 124, 89);"></td><td title="Index: [0, 4]&#10;Color: (232, 233, 153)" style="width: 20px; height: 20px;background-color: rgb(232, 233, 153);"></td><td title="Index: [0, 5]&#10;Color: (212, 123, 21)" style="width: 20px; height: 20px;background-color: rgb(212, 123, 21);"></td><td title="Index: [0, 6]&#10;Color: (46, 186, 255)" style="width: 20px; height: 20px;background-color: rgb(46, 186, 255);"></td><td title="Index: [0, 7]&#10;Color: (87, 130, 81)" style="width: 20px; height: 20px;background-color: rgb(87, 130, 81);"></td><td title="Index: [0, 8]&#10;Color: (233, 42, 244)" style="width: 20px; height: 20px;background-color: rgb(233, 42, 244);"></td><td title="Index: [0, 9]&#10;Color: (148, 31, 240)" style="width: 20px; height: 20px;background-color: rgb(148, 31, 240);"></td><td title="Index: [0, 10]&#10;Color: (138, 72, 79)" style="width: 20px; height: 20px;background-color: rgb(138, 72, 79);"></td><td title="Index: [0, 11]&#10;Color: (156, 167, 141)" style="width: 20px; height: 20px;background-color: rgb(156, 167, 141);"></td><td title="Index: [0, 12]&#10;Color: (99, 244, 191)" style="width: 20px; height: 20px;background-color: rgb(99, 244, 191);"></td><td title="Index: [0, 13]&#10;Color: (7, 121, 52)" style="width: 20px; height: 20px;background-color: rgb(7, 121, 52);"></td><td title="Index: [0, 14]&#10;Color: (61, 112, 167)" style="width: 20px; height: 20px;background-color: rgb(61, 112, 167);"></td><td title="Index: [0, 15]&#10;Color: (143, 95, 226)" style="width: 20px; height: 20px;background-color: rgb(143, 95, 226);"></td><td title="Index: [0, 16]&#10;Color: (39, 122, 31)" style="width: 20px; height: 20px;background-color: rgb(39, 122, 31);"></td><td title="Index: [0, 17]&#10;Color: (181, 206, 45)" style="width: 20px; height: 20px;background-color: rgb(181, 206, 45);"></td><td title="Index: [0, 18]&#10;Color: (252, 244, 226)" style="width: 20px; height: 20px;background-color: rgb(252, 244, 226);"></td><td title="Index: [0, 19]&#10;Color: (134, 48, 24)" style="width: 20px; height: 20px;background-color: rgb(134, 48, 24);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (142, 54, 71)" style="width: 20px; height: 20px;background-color: rgb(142, 54, 71);"></td><td title="Index: [1, 1]&#10;Color: (99, 177, 242)" style="width: 20px; height: 20px;background-color: rgb(99, 177, 242);"></td><td title="Index: [1, 2]&#10;Color: (134, 105, 186)" style="width: 20px; height: 20px;background-color: rgb(134, 105, 186);"></td><td title="Index: [1, 3]&#10;Color: (157, 227, 88)" style="width: 20px; height: 20px;background-color: rgb(157, 227, 88);"></td><td title="Index: [1, 4]&#10;Color: (35, 106, 170)" style="width: 20px; height: 20px;background-color: rgb(35, 106, 170);"></td><td title="Index: [1, 5]&#10;Color: (129, 204, 102)" style="width: 20px; height: 20px;background-color: rgb(129, 204, 102);"></td><td title="Index: [1, 6]&#10;Color: (178, 61, 209)" style="width: 20px; height: 20px;background-color: rgb(178, 61, 209);"></td><td title="Index: [1, 7]&#10;Color: (243, 185, 214)" style="width: 20px; height: 20px;background-color: rgb(243, 185, 214);"></td><td title="Index: [1, 8]&#10;Color: (221, 99, 132)" style="width: 20px; height: 20px;background-color: rgb(221, 99, 132);"></td><td t ...
