# %%
from IPython.display import HTML
HTML('<style>{}</style>'.format(open('custom.css').read()))
# Out:
# <style>html {
#   font-size: 62.5% !important; }
# body {
#   font-size: 1.5em !important; /* currently ems cause chrome bug misinterpreting rems on body element */
#   line-height: 1.6 !important;
#   font-weight: 400 !important;
#   font-family: "Raleway", "HelveticaNeue", "Helvetica Neue", Helvetica, Arial, sans-serif !important;
#   color: #222 !important; }
#
# div{ border-radius: 0px !important;  }
# div.CodeMirror-sizer{ background: rgb(244, 244, 248) !important; }
# div.input_area{ background: rgb(244, 244, 248) !important; }
#
# div.out_prompt_overlay:hover{ background: rgb(244, 244, 248) !important; }
# div.input_prompt:hover{ background: rgb(244, 244, 248) !important; }
#
# h1, h2, h3, h4, h5, h6 {
#   color: #333 !important;
#   margin-top: 0 !important;
#   margin-bottom: 2rem !important;
#   font-weight: 300 !important; }
# h1 { font-size: 4.0rem !important; line-height: 1.2 !important;  letter-spacing: -.1rem !important;}
# ...

# %% [markdown]
# <div style="text-align: center"><img src="https://www.python.org/static/img/python-logo.png"></div>

# %% [markdown]
# # Une introduction informelle au langage Python
#
# Python est un langage de programmation populaire qui est fiable, flexible, facile à apprendre. C'est un logiciel libre, disponible sur la plupart des OS. Il est soutenu par un communauté robuste et fournie de développeurs. Python permet tous les types de développement, que ce soit les applications web, les web services, les applications pour le bureau, les scripts, le traitement scientifique de données, les calepins Jupyter (comme celui que vous êtes en train de lire) et bien d'autres choses encore. Le langage Python est utilisé dans les universités, par les scientifiques, par des développeurs informatiques professionnels.
#
# Ce guide est une version francisée et librement adaptée du [tutoriel d'introduction à Python](https://docs.python.org/3.7/tutorial/introduction.html). L'avantage des calepins Jupyter est de pouvoir y éxécuter chaque cellule de code.
#
# Cette introduction est faite pour Python 3.7 mais devrait être valable avec toutes les version 3.x de Python
#
# Le matériau d'origine est sous Copyright (c) 2001-2019 Python Software Foundation.
#
# > **Attention** Ces calepins sont conçu pour que les cellules soient exécutées une par une, et certaines contiennent des erreurs délibérées à des fins de démonstration. En conséquence, si vous utilisez la commande **Cell** > **Run All** , certaines cellules ne seront pas exécutées.

# %% [markdown]
# ## Commentaires
#
# De nombreux exemples de ce notebook contiennent des commentaires. Les commentaires en python commencent par le caractère `#` et s'étendent jusqu'à la fin de la ligne. Voici un exemple de commentaires.
# Exécutez la cellule soit avec le bouton exécuter, soit en appuyant simultanément sur les touches majuscule et entrée.

# %%
# Voici le premier commentaire
spam = 1  # Puis un second commentaire
          # ... et un troisième !
text = "# Ce n'est pas un commentaire, car on est dans une variable de texte"
print(text)

# %% [markdown]
# ## Sommaire
#
# Chapitre 1 : [Le traitement des nombres](1_nombres.ipynb)
#
# Chapitre 2 : [Les chaines de caractère](2_chaines.ipynb)
#
# Chapitre 3 : [Les listes](3_listes.ipynb)
#
# Chapitre 4 : [Les boucles for](4_boucles.ipynb)
#
# Chapitre 5 : [Les srtuctures conditionnelles](5_tests.ipynb)
#
# Chapitre 6 : [Les structures conditionnelles chaînées](6_ifelseif.ipynb)
#
# Chapitre 7 : [Les fonctions](7_fonctions.ipynb)
#
# Chapitre 8 : [Les boucles while](8_boucle_while.ipynb)
#
# Chapitre 9 : [Les p-uplets](9_tuples.ipynb)
